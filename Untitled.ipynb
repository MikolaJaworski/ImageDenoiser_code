# %%
import os
import time
from glob import glob
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from skimage import io
import matplotlib.pyplot as plt
from sklearn.feature_extraction import image
from PIL import Image

# %%
path = './TrainingDataset'
img_path = os.sep.join([path, '0_input.jpg'])
print(img_path)
# Out:
# ./TrainingDataset/0_input.jpg

# %%
import cv2
img = io.imread(img_path)
img_norm = cv2.normalize(img, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
print(img_norm)
# Out:
# [[[0.07843138 0.23529413 0.13333334]
#   [0.01176471 0.16470589 0.08235294]
#   [0.09803922 0.24705884 0.20392159]
#   ...
#   [0.         0.09803922 0.00392157]
#   [0.         0.0509804  0.        ]
#   [0.05490196 0.18823531 0.08235294]]
#
#  [[0.03137255 0.19215688 0.13725491]
#   [0.11764707 0.28235295 0.24313727]
#   [0.1137255  0.27058825 0.26666668]
#   ...
#   [0.03921569 0.16862746 0.09411766]
#   [0.07843138 0.20784315 0.1254902 ]
#   [0.03921569 0.07843138 0.        ]]
#
#  [[0.13333334 0.30980393 0.32156864]
#   [0.20000002 0.37647063 0.40000004]
#   [0.23137257 0.40000004 0.46274513]
#   ...
#   [0.10980393 0.2392157  0.20392159]
#   [0.         0.12156864 0.07843138]
#   [0.04313726 0.05882353 0.        ]]
#
#  ...
#
#  [[0.6        0.59607846 0.5803922 ]
#   [0.76470596 0.7607844  0.7411765 ]
#   [0.7137255  0.7254902  0.69803923]
#   ...
#   [0.49411768 0.454902   0.45098042]
#   [0.5764706  0.5372549  0.53333336]
#   [0.4666667  0.5529412  0.5019608 ]]
#
#  [[0.49411768 0.4784314  0.4666667 ]
#   [0.42352945 0.41960788 0.4039216 ]
#   [0.7490196  0.75294125 0.7294118 ]
#   ...
#   [0.5254902  0.48627454 0.4901961 ]
#   [0.5686275  0.5254902  0.5411765 ]
#   [0.3921569  0.44705886 0.3803922 ]]
#
#  [[0.20784315 0.5137255  0.41176474]
#   [0.29411766 0.3921569  0.36862746]
#   [0.5764706  0.50980395 0.54901963]
#   ...
#   [0.18823531 0.23529413 0.18039216]
#   [0.38823533 0.43921572 0.26666668]
#   [0.15294118 0.37647063 0.2509804 ]]]

# %%
from skimage import img_as_ubyte
io.imsave('./img.jpg',img_as_ubyte(img))
io.imsave('./img_norm.jpg',img_as_ubyte(img_norm))
np.save('./img_norm.npy',img_norm)

# %%
img = io.imread('./img.jpg')
img_norm = io.imread('./img_norm.jpg')
img_norm_np = np.load('./img_norm.npy')

# %%
print(img_norm_np)
# Out:
# [[[0.07843138 0.23529413 0.13333334]
#   [0.01176471 0.16470589 0.08235294]
#   [0.09803922 0.24705884 0.20392159]
#   ...
#   [0.         0.09803922 0.00392157]
#   [0.         0.0509804  0.        ]
#   [0.05490196 0.18823531 0.08235294]]
#
#  [[0.03137255 0.19215688 0.13725491]
#   [0.11764707 0.28235295 0.24313727]
#   [0.1137255  0.27058825 0.26666668]
#   ...
#   [0.03921569 0.16862746 0.09411766]
#   [0.07843138 0.20784315 0.1254902 ]
#   [0.03921569 0.07843138 0.        ]]
#
#  [[0.13333334 0.30980393 0.32156864]
#   [0.20000002 0.37647063 0.40000004]
#   [0.23137257 0.40000004 0.46274513]
#   ...
#   [0.10980393 0.2392157  0.20392159]
#   [0.         0.12156864 0.07843138]
#   [0.04313726 0.05882353 0.        ]]
#
#  ...
#
#  [[0.6        0.59607846 0.5803922 ]
#   [0.76470596 0.7607844  0.7411765 ]
#   [0.7137255  0.7254902  0.69803923]
#   ...
#   [0.49411768 0.454902   0.45098042]
#   [0.5764706  0.5372549  0.53333336]
#   [0.4666667  0.5529412  0.5019608 ]]
#
#  [[0.49411768 0.4784314  0.4666667 ]
#   [0.42352945 0.41960788 0.4039216 ]
#   [0.7490196  0.75294125 0.7294118 ]
#   ...
#   [0.5254902  0.48627454 0.4901961 ]
#   [0.5686275  0.5254902  0.5411765 ]
#   [0.3921569  0.44705886 0.3803922 ]]
#
#  [[0.20784315 0.5137255  0.41176474]
#   [0.29411766 0.3921569  0.36862746]
#   [0.5764706  0.50980395 0.54901963]
#   ...
#   [0.18823531 0.23529413 0.18039216]
#   [0.38823533 0.43921572 0.26666668]
#   [0.15294118 0.37647063 0.2509804 ]]]

# %%
plt.imshow(img_norm_np)
print(img_norm_np.shape)
# Out:
# (481, 321, 3)

# %%
patch_input_imgs = image.extract_patches_2d(img_norm_np, (64, 64), max_patches=10, random_state=42)

# %%
print(patch_input_imgs.shape)
# Out:
# (10, 64, 64, 3)

# %%
print(patch_input_imgs)
# Out:
# [[[[0.5372549  0.49411768 0.5254902 ]
#    [0.35686275 0.3372549  0.36078432]
#    [0.36862746 0.37254903 0.38823533]
#    ...
#    [0.34117648 0.38823533 0.3803922 ]
#    [0.32156864 0.36078432 0.35686275]
#    [0.49411768 0.5176471  0.50980395]]
#
#   [[0.77647066 0.7411765  0.7607844 ]
#    [0.54509807 0.5372549  0.54901963]
#    [0.7607844  0.77647066 0.7725491 ]
#    ...
#    [0.30588236 0.3647059  0.3529412 ]
#    [0.28235295 0.32941177 0.32156864]
#    [0.32941177 0.3647059  0.3529412 ]]
#
#   [[0.35686275 0.32156864 0.3254902 ]
#    [0.29411766 0.29411766 0.28627452]
#    [0.3254902  0.34509805 0.32156864]
#    ...
#    [0.5254902  0.58431375 0.57254905]
#    [0.62352943 0.67058825 0.6627451 ]
#    [0.75294125 0.7960785  0.7725491 ]]
#
#   ...
#
#   [[0.6862745  0.7019608  0.7372549 ]
#    [0.8000001  0.8117648  0.83921576]
#    [0.7725491  0.78823537 0.8000001 ]
#    ...
#    [0.7254902  0.6666667  0.6862745 ]
#    [0.6901961  0.6313726  0.6431373 ]
#    [0.8352942  0.7803922  0.7803922 ]]
#
#   [[0.79215693 0.80392164 0.8313726 ]
#    [0.6901961  0.7019608  0.7294118 ]
#    [0.6862745  0.7019608  0.7137255 ]
#    ...
#    [0.6862745  0.67058825 0.6666667 ]
#    [0.7686275  0.75294125 0.7490196 ]
#    [0.7294118  0.7137255  0.7019608 ]]
#
#   [[0.4666667  0.4666667  0.49803925]
#    [0.3372549  0.34901962 0.37647063]
    def __init__(self, mode, load_mode, train_path, test_path, patch_n=None, patch_size=None, transform=None):

        self.patch_n = patch_n
        self.patch_size = patch_size
        self.transform = transform
        self.load_mode = load_mode
        

        if mode == 'train':
            input_ = sorted(glob(os.path.join(train_path, '*_input.npy')))
            target_ = sorted(glob(os.path.join(train_path, '*_target.npy')))
            if load_mode == 0: # batch data load
                self.input_ = input_
                self.target_ = target_
            else: # all data load
                self.input_ = [io.imread(f) for f in input_]
                self.target_ = [io.imread(f) for f in target_]
        else: # mode =='test'
            input_ = sorted(glob(os.path.join(test_path, '*_input.npy')))
            target_ = sorted(glob(os.path.join(test_path, '*_target.npy')))
            if load_mode == 0: # batch data load
                self.input_ = input_
                self.target_ = target_
            else: # all data load
                self.input_ = [np.load(f) for f in input_]
                self.target_ = [np.load(f) for f in target_]

   
    def __len__(self):
        return len(self.target_)
    



    def __getitem__(self, idx):
        input_img = self.input_[idx]
        target_img = self.target_[idx]
        
        if self.load_mode == 0:
            input_img = np.load(input_img)
            target_img = np.load(target_img)
        if self.transform:
                input_img = self.transform(input_img)
                target_img = self.transform(target_img)
        if self.patch_size:
            input_patches, target_patches = get_patch(input_img, target_img, self.patch_n, self.patch_size)
            return (input_patches, target_patches)
        else:
            return (input_img, target_img)    



def get_patch(full_input_img, full_target_img, patch_n, patch_size):
    patch_input_imgs = image.extract_patches_2d(full_input_img, (patch_size, patch_size), max_patches=patch_n, random_state=42)
    patch_target_imgs = image.extract_patches_2d(full_target_img, (patch_size, patch_size), max_patches=patch_n, random_state=42)
    return patch_input_imgs, patch_target_imgs


def get_loader(mode='train', load_mode=0,
               train_path='./TrainingDataset/', test_path='./TestDataset/',
               patch_n=40, patch_size=64,
               transform=None, batch_size=4, num_workers=4):
    dataset_ = ID_dataset(mode, load_mode, train_path, test_path, patch_n, patch_size, transform)
    data_loader = DataLoader(dataset=dataset_, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    return data_loader

# %%
patch_size = 64
total_iters = 0
data_loader = get_loader()
for iter_, (x, y) in enumerate(data_loader):
    
    total_iters += 1
    if total_iters % 49 == 0:
        print('Input: ' + str(x.size()) + ' Target: ' + str(y.size()))
        x1_np = x[1].numpy()
        y1_np = y[1].numpy()
        

        x = x.permute(0, 1, 4, 2, 3)
        y = y.permute(0, 1, 4, 2, 3)
        print('Input1: ' + str(x.size()) + ' Target1: ' + str(y.size()))
        x2_np = x[1].numpy()
        y2_np = y[1].numpy()

        if patch_size: # patch training
            x = x.view(-1, 3, patch_size, patch_size)
            y = y.view(-1, 3, patch_size, patch_size)
        print('Input2: ' + str(x.size()) + ' Target2: ' + str(y.size()))
        x3_np = x[1].numpy()
        y3_np = y[1].numpy()

print(total_iters)
# Out:
# Input: torch.Size([4, 40, 64, 64, 3]) Target: torch.Size([4, 40, 64, 64, 3])
# Input1: torch.Size([4, 40, 3, 64, 64]) Target1: torch.Size([4, 40, 3, 64, 64])
# Input2: torch.Size([160, 3, 64, 64]) Target2: torch.Size([160, 3, 64, 64])
# 50

# %%
print(x1_np.shape)
# Out:
# (40, 64, 64, 3)

# %%
plt.imshow(x1_np[5])

# %%
plt.imshow(y1_np[5])

# %%
plt.imshow(np.moveaxis(x2_np[5],0, -1))

# %%
print(x2_np.shape)
# Out:
# (40, 3, 64, 64)

# %%
print(x3_np.shape)
# Out:
# (3, 64, 64)

# %%
plt.imshow(np.moveaxis(x3_np,0, -1))

# %%
plt.imshow(x1_np[39])

# %%
import os
import time
from glob import glob
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from skimage import io
import matplotlib.pyplot as plt
from sklearn.feature_extraction import image
from skimage.transform import resize
from PIL import Image

# %%
class ID_dataset(Dataset):
    def __init__(self, mode, load_mode, train_path, test_path, patch_n=None, patch_size=None, transform=None):

        self.patch_n = patch_n
        self.patch_size = patch_size
        self.transform = transform
        self.load_mode = load_mode
        

        if mode == 'train':
            input_ = sorted(glob(os.path.join(train_path, '*_input.npy')))
            target_ = sorted(glob(os.path.join(train_path, '*_target.npy')))
            if load_mode == 0: # batch data load
                self.input_ = input_
                self.target_ = target_
            else: # all data load
                self.input_ = [io.imread(f) for f in input_]
                self.target_ = [io.imread(f) for f in target_]
        else: # mode =='test'
            input_ = sorted(glob(os.path.join(test_path, '*_input.npy')))
            target_ = sorted(glob(os.path.join(test_path, '*_target.npy')))
            if load_mode == 0: # batch data load
                self.input_ = input_
                self.target_ = target_
            else: # all data load
                self.input_ = [np.load(f) for f in input_]
                self.target_ = [np.load(f) for f in target_]

   
    def __len__(self):
        return len(self.target_)
    

    def __getitem__(self, idx):
        input_img = self.input_[idx]
        target_img = self.target_[idx]
        
        if self.load_mode == 0:
            input_img = np.load(input_img)
            target_img = np.load(target_img)
        if self.transform:
                input_img = resize(input_img, (254, 254))
                target_img = resize(target_img, (254, 254))
        if self.patch_size:
            input_patches, target_patches = get_patch(input_img, target_img, self.patch_n, self.patch_size)
            return (input_patches, target_patches)
        else:
            return (input_img, target_img)    



def get_patch(full_input_img, full_target_img, patch_n, patch_size):
    patch_input_imgs = image.extract_patches_2d(full_input_img, (patch_size, patch_size), max_patches=patch_n, random_state=42)
    patch_target_imgs = image.extract_patches_2d(full_target_img, (patch_size, patch_size), max_patches=patch_n, random_state=42)
    return patch_input_imgs, patch_target_imgs


def get_loader(mode='train', load_mode=0,
               train_path='./TrainingDataset/', test_path='./TestDataset/',
               patch_n=20, patch_size=64,
               transform=None, batch_size=4, num_workers=4):
    dataset_ = ID_dataset(mode, load_mode, train_path, test_path, patch_n, patch_size, transform)
    data_loader = DataLoader(dataset=dataset_, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    return data_loader

# %%
class ID_net(nn.Module):
    def __init__(self, out_ch=96):
        super(ID_net, self).__init__()
        self.conv_first = nn.Conv2d(3, out_ch, kernel_size=5, stride=1, padding=0)
        self.conv = nn.Conv2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.conv_t = nn.ConvTranspose2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.conv_t_last = nn.ConvTranspose2d(out_ch, 3, kernel_size=5, stride=1, padding=0)
        self.relu = nn.ReLU()

    def forward(self, x):
        # encoder
        residual_1 = x.clone()
        out = self.relu(self.conv_first(x))
        out = self.relu(self.conv(out))
        residual_2 = out.clone()
        out = self.relu(self.conv(out))
        out = self.relu(self.conv(out))
        residual_3 = out.clone()
        out = self.relu(self.conv(out))

        # decoder
        out = self.conv_t(out)
        out += residual_3
        out = self.conv_t(self.relu(out))
        out = self.conv_t(self.relu(out))
        out += residual_2
        out = self.conv_t(self.relu(out))
        out = self.conv_t_last(self.relu(out))
        out += residual_1
        out = self.relu(out)
        return out

# %%
def compute_measure(x, y, pred, data_range):
    original_psnr = compute_PSNR(x, y, data_range)
    original_rmse = compute_RMSE(x, y)
    pred_psnr = compute_PSNR(pred, y, data_range)
    pred_rmse = compute_RMSE(pred, y)
    return (original_psnr, original_rmse), (pred_psnr, pred_rmse)


def compute_MSE(img1, img2):
    return ((img1 - img2) ** 2).mean()


def compute_RMSE(img1, img2):
    if type(img1) == torch.Tensor:
        return torch.sqrt(compute_MSE(img1, img2)).item()
    else:
        return np.sqrt(compute_MSE(img1, img2))


def compute_PSNR(img1, img2, data_range):
    if type(img1) == torch.Tensor:
        mse_ = compute_MSE(img1, img2)
        return 10 * torch.log10((data_range ** 2) / mse_).item()
    else:
        mse_ = compute_MSE(img1, img2)
        return 10 * np.log10((data_range ** 2) / mse_)

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /home/jawor96/Documents/StudyICM/PracaMagisterska/ImageDenoiser

# %%
PATH = './ID_net.pth'
device = torch.device('cpu')
net = ID_net()
net.load_state_dict(torch.load(PATH, map_location=device))


def test(net):
    testData = get_loader(mode='test', load_mode=1, transform=True ,batch_size=1, num_workers=4, patch_n=None, patch_size=None)
    total_iters = 0
    ori_psnr_avg, ori_rmse_avg = 0, 0
    pred_psnr_avg, pred_rmse_avg = 0, 0

    with torch.no_grad():
        for iter_, (x, y) in enumerate(testData):
            total_iters += 1    
            x = x.permute(0, 3, 1, 2).float()
            y = y.permute(0, 3, 1, 2).float()
            pred = net(x)
            original_result, pred_result = compute_measure(x, y, pred, 1)
            ori_psnr_avg += original_result[0]
            ori_rmse_avg += original_result[1]
            pred_psnr_avg += pred_result[0]
            pred_rmse_avg += pred_result[1]

            if total_iters % 20 == 0:
                print('Input: ' + str(x.size()) + ' Target: ' + str(y.size()) + ' Pred: ' + str(pred.size()))
                x = x.permute(0, 2, 3, 1)
                y = y.permute(0, 2, 3, 1)
                pred = pred.permute(0, 2, 3, 1)
                print('Input: ' + str(x.size()) + ' Target: ' + str(y.size()) + ' Pred: ' + str(pred.size()))

                inpu = x.numpy()
                targ = y.numpy()
                pre = pred.numpy()
                figu = plt.figure()
                figu.add_subplot(1, 3, 1)
                plt.imshow(inpu[0])
                figu.add_subplot(1, 3, 2)
                plt.imshow(targ[0])
                figu.add_subplot(1, 3, 3)
                plt.imshow(pre[0])
                plt.show()
            print('\n')
            print('Original\nPSNR avg: {:.4f}\nRMSE avg: {:.4f}'.format(ori_psnr_avg/len(testData), ori_rmse_avg/len(testData)))
            print('After learning\nPSNR avg: {:.4f}\nRMSE avg: {:.4f}'.format(pred_psnr_avg/len(testData), pred_rmse_avg/len(testData)))
             


    print(total_iters)

# %%
test(net)
# Out:
# Original
# PSNR avg: 0.2468
# RMSE avg: 0.0006
# After learning
# PSNR avg: 0.2851
# RMSE avg: 0.0004
#
#
# Original
# PSNR avg: 0.4927
# RMSE avg: 0.0012
# After learning
# PSNR avg: 0.5757
# RMSE avg: 0.0007
#
#
# Original
# PSNR avg: 0.7403
# RMSE avg: 0.0018
# After learning
# PSNR avg: 0.8512
# RMSE avg: 0.0011
#
#
# Original
# PSNR avg: 0.9865
# RMSE avg: 0.0023
# After learning
# PSNR avg: 1.1345
# RMSE avg: 0.0015
#
#
# Original
# PSNR avg: 1.2326
# RMSE avg: 0.0029
# After learning
# PSNR avg: 1.4250
# RMSE avg: 0.0019
#
#
# Original
# PSNR avg: 1.4775
# RMSE avg: 0.0035
# After learning
# PSNR avg: 1.7160
# RMSE avg: 0.0022
#
#
# Original
# PSNR avg: 1.7237
# RMSE avg: 0.0041
# After learning
# PSNR avg: 1.9912
# RMSE avg: 0.0027
#
#
# Original
# PSNR avg: 1.9711
# RMSE avg: 0.0047
# After learning
# PSNR avg: 2.2771
# RMSE avg: 0.0030
#
#
# Original
# PSNR avg: 2.2183
# RMSE avg: 0.0053
# After learning
# PSNR avg: 2.5529
# RMSE avg: 0.0034
#
#
# Original
# PSNR avg: 2.4648
# RMSE avg: 0.0059
# After learning
# PSNR avg: 2.8323
# RMSE avg: 0.0038
#
#
# Original
# PSNR avg: 2.7148
# RMSE avg: 0.0064
# After learning
# PSNR avg: 3.1357
# RMSE avg: 0.0041
#
#
# Original
# PSNR avg: 2.9627
# RMSE avg: 0.0070
# After learning
# PSNR avg: 3.3896
# RMSE avg: 0.0047
#
#
# Original
# PSNR avg: 3.2084
# RMSE avg: 0.0076
# After learning
# PSNR avg: 3.6773
# RMSE avg: 0.0051
#
#
# Original
# PSNR avg: 3.4560
# RMSE avg: 0.0082
# After learning
# PSNR avg: 3.9551
# RMSE avg: 0.0055
#
#
# Original
# PSNR avg: 3.7022
# RMSE avg: 0.0088
# After learning
# PSNR avg: 4.2497
# RMSE avg: 0.0058
#
#
# Original
# PSNR avg: 3.9501
# RMSE avg: 0.0093
# After learning
# PSNR avg: 4.5326
# RMSE avg: 0.0062
#
#
# Original
# PSNR avg: 4.1970
# RMSE avg: 0.0099
# After learning
# PSNR avg: 4.8095
# RMSE avg: 0.0066
#
#
# Original
# PSNR avg: 4.4478
# RMSE avg: 0.0105
# After learning
# PSNR avg: 5.0778
# RMSE avg: 0.0070
#
#
# Original
# PSNR avg: 4.6961
# RMSE avg: 0.0110
# After learning
# PSNR avg: 5.3734
# RMSE avg: 0.0074
# Input: torch.Size([1, 3, 254, 254]) Target: torch.Size([1, 3, 254, 254]) Pred: torch.Size([1, 3, 254, 254])
# Input: torch.Size([1, 254, 254, 3]) Target: torch.Size([1, 254, 254, 3]) Pred: torch.Size([1, 254, 254, 3])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original
# PSNR avg: 4.9444
# RMSE avg: 0.0116
# After learning
# PSNR avg: 5.6511
# RMSE avg: 0.0078
#
#
# Original
# PSNR avg: 5.1915
# RMSE avg: 0.0122
# After learning
# PSNR avg: 5.9475
# RMSE avg: 0.0081
#
#
# Original
# PSNR avg: 5.4369
# RMSE avg: 0.0128
# After learning
# PSNR avg: 6.2289
# RMSE avg: 0.0085
#
#
# Original
# PSNR avg: 5.6824
# RMSE avg: 0.0134
# After learning
# PSNR avg: 6.4957
# RMSE avg: 0.0090
#
#
# Original
# PSNR avg: 5.9284
# RMSE avg: 0.0140
# After learning
# PSNR avg: 6.7696
# RMSE avg: 0.0094
#
#
# Original
# PSNR avg: 6.1773
# RMSE avg: 0.0145
# After learning
# PSNR avg: 7.0660
# RMSE avg: 0.0097
#
#
# Original
# PSNR avg: 6.4255
# RMSE avg: 0.0151
# After learning
# PSNR avg: 7.3524
# RMSE avg: 0.0101
#
#
# Original
# PSNR avg: 6.6720
# RMSE avg: 0.0157
# After learning
# PSNR avg: 7.6097
# RMSE avg: 0.0106
#
#
# Original
# PSNR avg: 6.9189
# RMSE avg: 0.0163
# After learning
# PSNR avg: 7.9000
# RMSE avg: 0.0110
#
#
# Original
# PSNR avg: 7.1663
# RMSE avg: 0.0169
# After learning
# PSNR avg: 8.1851
# RMSE avg: 0.0113
#
#
# Original
# PSNR avg: 7.4110
# RMSE avg: 0.0175
# After learning
# PSNR avg: 8.4812
# RMSE avg: 0.0117
#
#
# Original
# PSNR avg: 7.6674
# RMSE avg: 0.0180
# After learning
# PSNR avg: 8.7829
# RMSE avg: 0.0120
#
#
# Original
# PSNR avg: 7.9130
# RMSE avg: 0.0186
# After learning
# PSNR avg: 9.0659
# RMSE avg: 0.0124
#
#
# Original
# PSNR avg: 8.1637
# RMSE avg: 0.0191
# After learning
# PSNR avg: 9.3503
# RMSE avg: 0.0128
#
#
# Original
# PSNR avg: 8.4121
# RMSE avg: 0.0197
# After learning
# PSNR avg: 9.6498
# RMSE avg: 0.0131
#
#
# Original
# PSNR avg: 8.6573
# RMSE avg: 0.0203
# After learning
# PSNR avg: 9.9444
# RMSE avg: 0.0134
#
#
# Original
# PSNR avg: 8.9033
# RMSE avg: 0.0209
# After learning
# PSNR avg: 10.2270
# RMSE avg: 0.0138
#
#
# Original
# PSNR avg: 9.1486
# RMSE avg: 0.0215
# After learning
# PSNR avg: 10.5258
# RMSE avg: 0.0141
#
#
# Original
# PSNR avg: 9.3932
# RMSE avg: 0.0221
# After learning
# PSNR avg: 10.8187
# RMSE avg: 0.0145
#
#
# Original
# PSNR avg: 9.6393
# RMSE avg: 0.0227
# After learning
# PSNR avg: 11.0922
# RMSE avg: 0.0149
# Input: torch.Size([1, 3, 254, 254]) Target: torch.Size([1, 3, 254, 254]) Pred: torch.Size([1, 3, 254, 254])
# Input: torch.Size([1, 254, 254, 3]) Target: torch.Size([1, 254, 254, 3]) Pred: torch.Size([1, 254, 254, 3])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original
# PSNR avg: 9.8882
# RMSE avg: 0.0232
# After learning
# PSNR avg: 11.3806
# RMSE avg: 0.0152
#
#
# Original
# PSNR avg: 10.1343
# RMSE avg: 0.0238
# After learning
# PSNR avg: 11.6755
# RMSE avg: 0.0156
#
#
# Original
# PSNR avg: 10.3797
# RMSE avg: 0.0244
# After learning
# PSNR avg: 11.9771
# RMSE avg: 0.0159
#
#
# Original
# PSNR avg: 10.6255
# RMSE avg: 0.0250
# After learning
# PSNR avg: 12.2618
# RMSE avg: 0.0163
#
#
# Original
# PSNR avg: 10.8706
# RMSE avg: 0.0256
# After learning
# PSNR avg: 12.5578
# RMSE avg: 0.0166
#
#
# Original
# PSNR avg: 11.1165
# RMSE avg: 0.0262
# After learning
# PSNR avg: 12.8426
# RMSE avg: 0.0170
#
#
# Original
# PSNR avg: 11.3641
# RMSE avg: 0.0268
# After learning
# PSNR avg: 13.1287
# RMSE avg: 0.0173
#
#
# Original
# PSNR avg: 11.6107
# RMSE avg: 0.0274
# After learning
# PSNR avg: 13.4069
# RMSE avg: 0.0178
#
#
# Original
# PSNR avg: 11.8596
# RMSE avg: 0.0279
# After learning
# PSNR avg: 13.6729
# RMSE avg: 0.0182
#
#
# Original
# PSNR avg: 12.1091
# RMSE avg: 0.0285
# After learning
# PSNR avg: 13.9518
# RMSE avg: 0.0186
#
#
# Original
# PSNR avg: 12.3547
# RMSE avg: 0.0291
# After learning
# PSNR avg: 14.2299
# RMSE avg: 0.0190
#
#
# Original
# PSNR avg: 12.6020
# RMSE avg: 0.0297
# After learning
# PSNR avg: 14.5261
# RMSE avg: 0.0194
#
#
# Original
# PSNR avg: 12.8518
# RMSE avg: 0.0302
# After learning
# PSNR avg: 14.8060
# RMSE avg: 0.0198
#
#
# Original
# PSNR avg: 13.0968
# RMSE avg: 0.0308
# After learning
# PSNR avg: 15.0992
# RMSE avg: 0.0201
#
#
# Original
# PSNR avg: 13.3452
# RMSE avg: 0.0314
# After learning
# PSNR avg: 15.3736
# RMSE avg: 0.0205
#
#
# Original
# PSNR avg: 13.5916
# RMSE avg: 0.0320
# After learning
# PSNR avg: 15.6576
# RMSE avg: 0.0209
#
#
# Original
# PSNR avg: 13.8370
# RMSE avg: 0.0326
# After learning
# PSNR avg: 15.9311
# RMSE avg: 0.0213
#
#
# Original
# PSNR avg: 14.0846
# RMSE avg: 0.0332
# After learning
# PSNR avg: 16.2005
# RMSE avg: 0.0218
#
#
# Original
# PSNR avg: 14.3295
# RMSE avg: 0.0337
# After learning
# PSNR avg: 16.4903
# RMSE avg: 0.0221
#
#
# Original
# PSNR avg: 14.5765
# RMSE avg: 0.0343
# After learning
# PSNR avg: 16.7696
# RMSE avg: 0.0225
# Input: torch.Size([1, 3, 254, 254]) Target: torch.Size([1, 3, 254, 254]) Pred: torch.Size([1, 3, 254, 254])
# Input: torch.Size([1, 254, 254, 3]) Target: torch.Size([1, 254, 254, 3]) Pred: torch.Size([1, 254, 254, 3])
# Original
# PSNR avg: 14.8234
# RMSE avg: 0.0349
# After learning
# PSNR avg: 17.0578
# RMSE avg: 0.0229
#
#
# Original
# PSNR avg: 15.0695
# RMSE avg: 0.0355
# After learning
# PSNR avg: 17.3117
# RMSE avg: 0.0234
#
#
# Original
# PSNR avg: 15.3193
# RMSE avg: 0.0361
# After learning
# PSNR avg: 17.5857
# RMSE avg: 0.0239
#
#
# Original
# PSNR avg: 15.5646
# RMSE avg: 0.0367
# After learning
# PSNR avg: 17.8712
# RMSE avg: 0.0242
#
#
# Original
# PSNR avg: 15.8112
# RMSE avg: 0.0372
# After learning
# PSNR avg: 18.1458
# RMSE avg: 0.0247
#
#
# Original
# PSNR avg: 16.0563
# RMSE avg: 0.0378
# After learning
# PSNR avg: 18.4238
# RMSE avg: 0.0251
#
#
# Original
# PSNR avg: 16.3032
# RMSE avg: 0.0384
# After learning
# PSNR avg: 18.7076
# RMSE avg: 0.0255
#
#
# Original
# PSNR avg: 16.5499
# RMSE avg: 0.0390
# After learning
# PSNR avg: 18.9758
# RMSE avg: 0.0259
#
#
# Original
# PSNR avg: 16.8080
# RMSE avg: 0.0395
# After learning
# PSNR avg: 19.2717
# RMSE avg: 0.0262
#
#
# Original
# PSNR avg: 17.0528
# RMSE avg: 0.0401
# After learning
# PSNR avg: 19.5626
# RMSE avg: 0.0266
#
#
# Original
# PSNR avg: 17.2988
# RMSE avg: 0.0407
# After learning
# PSNR avg: 19.8433
# RMSE avg: 0.0270
#
#
# Original
# PSNR avg: 17.5477
# RMSE avg: 0.0413
# After learning
# PSNR avg: 20.1248
# RMSE avg: 0.0274
#
#
# Original
# PSNR avg: 17.7928
# RMSE avg: 0.0419
# After learning
# PSNR avg: 20.3852
# RMSE avg: 0.0279
#
#
# Original
# PSNR avg: 18.0414
# RMSE avg: 0.0424
# After learning
# PSNR avg: 20.6731
# RMSE avg: 0.0282
#
#
# Original
# PSNR avg: 18.2895
# RMSE avg: 0.0430
# After learning
# PSNR avg: 20.9516
# RMSE avg: 0.0286
#
#
# Original
# PSNR avg: 18.5378
# RMSE avg: 0.0436
# After learning
# PSNR avg: 21.2454
# RMSE avg: 0.0290
#
#
# Original
# PSNR avg: 18.7925
# RMSE avg: 0.0441
# After learning
# PSNR avg: 21.5422
# RMSE avg: 0.0293
#
#
# Original
# PSNR avg: 19.0388
# RMSE avg: 0.0447
# After learning
# PSNR avg: 21.8240
# RMSE avg: 0.0297
#
#
# Original
# PSNR avg: 19.2871
# RMSE avg: 0.0453
# After learning
# PSNR avg: 22.1240
# RMSE avg: 0.0300
#
#
# Original
# PSNR avg: 19.5380
# RMSE avg: 0.0458
# After learning
# PSNR avg: 22.4107
# RMSE avg: 0.0304
# Input: torch.Size([1, 3, 254, 254]) Target: torch.Size([1, 3, 254, 254]) Pred: torch.Size([1, 3, 254, 254])
# Input: torch.Size([1, 254, 254, 3]) Target: torch.Size([1, 254, 254, 3]) Pred: torch.Size([1, 254, 254, 3])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original
# PSNR avg: 19.7844
# RMSE avg: 0.0464
# After learning
# PSNR avg: 22.6960
# RMSE avg: 0.0308
#
#
# Original
# PSNR avg: 20.0304
# RMSE avg: 0.0470
# After learning
# PSNR avg: 22.9874
# RMSE avg: 0.0311
#
#
# Original
# PSNR avg: 20.2752
# RMSE avg: 0.0476
# After learning
# PSNR avg: 23.2866
# RMSE avg: 0.0314
#
#
# Original
# PSNR avg: 20.5228
# RMSE avg: 0.0482
# After learning
# PSNR avg: 23.5621
# RMSE avg: 0.0319
#
#
# Original
# PSNR avg: 20.7697
# RMSE avg: 0.0488
# After learning
# PSNR avg: 23.8488
# RMSE avg: 0.0322
#
#
# Original
# PSNR avg: 21.0154
# RMSE avg: 0.0494
# After learning
# PSNR avg: 24.1331
# RMSE avg: 0.0326
#
#
# Original
# PSNR avg: 21.2647
# RMSE avg: 0.0499
# After learning
# PSNR avg: 24.4065
# RMSE avg: 0.0330
#
#
# Original
# PSNR avg: 21.5115
# RMSE avg: 0.0505
# After learning
# PSNR avg: 24.6679
# RMSE avg: 0.0335
#
#
# Original
# PSNR avg: 21.7585
# RMSE avg: 0.0511
# After learning
# PSNR avg: 24.9469
# RMSE avg: 0.0339
#
#
# Original
# PSNR avg: 22.0116
# RMSE avg: 0.0516
# After learning
# PSNR avg: 25.2043
# RMSE avg: 0.0344
#
#
# Original
# PSNR avg: 22.2572
# RMSE avg: 0.0522
# After learning
# PSNR avg: 25.4905
# RMSE avg: 0.0348
#
#
# Original
# PSNR avg: 22.5035
# RMSE avg: 0.0528
# After learning
# PSNR avg: 25.7700
# RMSE avg: 0.0352
#
#
# Original
# PSNR avg: 22.7485
# RMSE avg: 0.0534
# After learning
# PSNR avg: 26.0471
# RMSE avg: 0.0356
#
#
# Original
# PSNR avg: 22.9968
# RMSE avg: 0.0540
# After learning
# PSNR avg: 26.3298
# RMSE avg: 0.0360
#
#
# Original
# PSNR avg: 23.2414
# RMSE avg: 0.0546
# After learning
# PSNR avg: 26.6198
# RMSE avg: 0.0364
#
#
# Original
# PSNR avg: 23.4874
# RMSE avg: 0.0552
# After learning
# PSNR avg: 26.9171
# RMSE avg: 0.0367
#
#
# Original
# PSNR avg: 23.7367
# RMSE avg: 0.0557
# After learning
# PSNR avg: 27.1818
# RMSE avg: 0.0372
#
#
# Original
# PSNR avg: 23.9834
# RMSE avg: 0.0563
# After learning
# PSNR avg: 27.4564
# RMSE avg: 0.0376
#
#
# Original
# PSNR avg: 24.2326
# RMSE avg: 0.0569
# After learning
# PSNR avg: 27.7491
# RMSE avg: 0.0379
#
#
# Original
# PSNR avg: 24.4825
# RMSE avg: 0.0575
# After learning
# PSNR avg: 28.0245
# RMSE avg: 0.0384
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Input: torch.Size([1, 3, 254, 254]) Target: torch.Size([1, 3, 254, 254]) Pred: torch.Size([1, 3, 254, 254])
# Input: torch.Size([1, 254, 254, 3]) Target: torch.Size([1, 254, 254, 3]) Pred: torch.Size([1, 254, 254, 3])
# Original
# PSNR avg: 24.7326
# RMSE avg: 0.0580
# After learning
# PSNR avg: 28.2861
# RMSE avg: 0.0388
# 100
